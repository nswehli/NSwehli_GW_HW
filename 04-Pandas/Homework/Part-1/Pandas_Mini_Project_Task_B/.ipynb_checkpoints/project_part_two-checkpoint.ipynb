# %%
# Dependencies
import pandas as pd

# %%
# load CSV
file="Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
df= pd.read_csv(file)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (21,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
df.columns
df_reduced=df.iloc[:, [0, 1, 2, 3, 4, 6,7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
df_reduced.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampFullJobAfter',
#        'BootcampLoanYesNo', 'BootcampName', 'BootcampPostSalary',
#        'BootcampRecommend', 'ChildrenNumber', 'CityPopulation',
#        'CodeEventBootcamp', 'CountryLive', 'EmploymentField',
#        'EmploymentStatus', 'Gender', 'HasChildren', 'HoursLearning', 'Income',
#        'JobRoleInterest', 'SchoolDegree', 'SchoolMajor'],
#       dtype='object')

# %%
# Change reading 0 and 1 to No and Yes, respectively
df_reduced=df_reduced.replace({0: "No", 1:"Yes"})
df_reduced.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo BootcampName  BootcampPostSalary BootcampRecommend  \
# 0               NaN          NaN                 NaN               NaN
# 1               NaN          NaN                 NaN               NaN
# 2               NaN          NaN                 NaN               NaN
# 3               NaN          NaN                 NaN               NaN
# 4               NaN          NaN                 NaN               NaN
#
#   ChildrenNumber                 CityPopulation  ...  \
# 0            NaN  between 100,000 and 1 million  ...
# 1            NaN  between 100,000 and 1 million  ...
# 2            NaN            more than 1 million  ...
# 3            NaN            more than 1 million  ...
# 4            NaN  between 100,000 and 1 million  ...
#
#                 CountryLive                        EmploymentField  \
# 0  United States of America      office and administrative support
# 1  United States of America                      food and beverage
# 2  United States of America                                finance
# 3  United States of America  arts, entertainment, sports, or media
# 4  United States of America                              education
#
#      EmploymentStatus  Gender HasChildren HoursLearning   Income  \
# 0  Employed for wages    male          No            30  32000.0
# 1  Employed for wages    male         NaN            30  15000.0
# 2  Employed for wages    male         NaN            20  48000.0
# 3  Employed for wages  female         NaN            20  43000.0
# 4  Employed for wages  female         NaN            25   6000.0
#
#              JobRoleInterest                             SchoolDegree  \
# 0                        NaN           some college credit, no degree
# 1    Front-End Web Developer           some college credit, no degree
# 2                        NaN  high school diploma or equivalent (GED)
# 3    Front-End Web Developer                        bachelor's degree
# 4   Full-Stack Web Developer           some college credit, no degree
#
#                SchoolMajor
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3  Cinematography And Film
# 4                      NaN
#
# [5 rows x 21 columns]

# %%
# Extract rows for only those who attended a bootcamp
BTatended = df_reduced.loc[(df_reduced["AttendedBootcamp"] == "Yes")]

BTatended.head()
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93   32.0              Yes            Yes                   No
# 97   26.0              Yes            Yes                  Yes
# 130  41.0              Yes            Yes                  Yes
# 159  26.0              Yes            Yes                   No
# 188  24.0              Yes             No                  NaN
#
#     BootcampLoanYesNo      BootcampName  BootcampPostSalary BootcampRecommend  \
# 93                 No    Codify Academy                 NaN                No
# 97                 No    DaVinci Coders             45000.0                No
# 130               Yes     Coder Foundry             75000.0               Yes
# 159                No  General Assembly                 NaN                No
# 188               Yes               NaN                 NaN                No
#
#     ChildrenNumber                 CityPopulation  ...  \
# 93             NaN  between 100,000 and 1 million  ...
# 97             NaN            more than 1 million  ...
# 130              3              less than 100,000  ...
# 159            NaN  between 100,000 and 1 million  ...
# 188            NaN  between 100,000 and 1 million  ...
#
#                   CountryLive                        EmploymentField  \
# 93   United States of America  arts, entertainment, sports, or media
# 97   United States of America                   software development
# 130  United States of America                   software development
# 159  United States of America                                    NaN
# 188                    Canada                                    NaN
#
#                          EmploymentStatus  Gender HasChildren HoursLearning  \
# 93           Self-employed business owner    male         NaN            20
# 97                     Employed for wages    male          No            10
# 130                    Employed for wages    male         Yes            30
# 159  Not working and not looking for work  female         NaN            30
# 188      Not working but looking for work  female         NaN            60
#
#       Income           JobRoleInterest                        SchoolDegree  \
# 93   67000.0                       NaN                   bachelor's degree
# 97   40000.0                       NaN  master's degree (non-professional)
# 130  75000.0                       NaN      some college credit, no degree
# 159      NaN  Full-Stack Web Developer      some college credit, no degree
# 188      NaN                       NaN      some college credit, no degree
#
#     SchoolMajor
# 93      Biology
# 97        Music
# 130         NaN
# 159         NaN
# 188         NaN
#
# [5 rows x 21 columns]

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
BTatended=BTatended.replace('Free Code Camp is not a bootcamp - please scroll up and change answer to "no"','Free Code Camp')
camps =BTatended.groupby(["BootcampName"])
camps=camps.count()
camps=camps.sort_values("AttendedBootcamp",ascending=False)
camps=camps.loc[(camps["AttendedBootcamp"] > 10)]

camps=camps["AttendedBootcamp"]

camps
# Out:
# BootcampName
# General Assembly                  90
# Flatiron School                   54
# Dev Bootcamp                      48
# The Iron Yard                     40
# Prime Digital Academy             30
# Hack Reactor                      29
# Turing                            27
# App Academy                       22
# Hackbright Academy                22
# Bloc.io                           21
# Code Fellows                      21
# MakerSquare                       20
# Galvanize                         20
# New York Code + Design Academy    20
# Coding Dojo                       18
# The Firehose Project              16
# Free Code Camp                    15
# Epicodus                          14
# Dev Academy                       13
# Makers Academy                    12
# Tech Talent South                 12
# Coder Camps                       11
# Name: AttendedBootcamp, dtype: int64

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
BTrecommend = BTatended.loc[(BTatended["BootcampRecommend"] == "Yes")]
recom =BTrecommend.groupby(["BootcampName"])
recom=recom.count()
recom=recom.sort_values("BootcampRecommend",ascending=False)
#recom=recom.loc[(recom["BootcampRecommend"] > 10)]
recom=recom ["BootcampRecommend"]
recom
# Out:
# BootcampName
# General Assembly                                 70
# Flatiron School                                  50
# Dev Bootcamp                                     41
# The Iron Yard                                    31
# Hack Reactor                                     27
# Turing                                           26
# Prime Digital Academy                            25
# App Academy                                      20
# Hackbright Academy                               19
# MakerSquare                                      18
# Code Fellows                                     15
# Free Code Camp                                   14
# New York Code + Design Academy                   14
# Dev Academy                                      13
# The Firehose Project                             13
# Makers Academy                                   12
# Coding Dojo                                      11
# Epicodus                                         11
# Galvanize                                        11
# Bloc.io                                          11
# Viking Code School                               10
# CodeaCamp                                         8
# Ada                                               8
# Tech Talent South                                 8
# Launch Academy                                    8
# Software Guild                                    8
# DevMountain                                       8
# Fullstack Academy                                 6
# Codeup                                            6
# Coder Camps                                       6
#                                                  ..
# Base10 Academy                                    1
# The Data Incubator                                1
# Starter League                                    1
# Operation Spark                                   1
# Ruby On The Beach                                 1
# Claim Academy                                     1
# Fire Bootcamp                                     1
# Digital House                                     1
# Founders & Coders                                 1
# DESIGNATION                                       1
# Coding House                                      1
# Codify Academy                                    1
# Coder's Lab                                       1
# Coder Foundry                                     1
# HackerYou                                         1
# CodeMasters Academy                               1
# Ladies Learning Code                              1
# CodeCraft School                                  1
# Launch School (formerly Tealeaf Academy)          1
# Le Wagon                                          1
# LearningFuze                                      1
# Code Union                                        1
# Metis                                             1
# Microsoft Research Data Science Summer School     1
# Mobile Makers Academy                             1
# Code Institute                                    1
# Code 42                                           1
# Origin Code Academy                               1
# PDX Code Guild                                    1
# tradecraft                                        1
# Name: BootcampRecommend, Length: 116, dtype: int64

# %%
# Merge the two created data frames on the name of tbe bootcamp
merge_table = pd.merge(camps, recom, on="BootcampName")

merge_table
# Out:
#                                 AttendedBootcamp  BootcampRecommend
# BootcampName
# General Assembly                              90                 70
# Flatiron School                               54                 50
# Dev Bootcamp                                  48                 41
# The Iron Yard                                 40                 31
# Prime Digital Academy                         30                 25
# Hack Reactor                                  29                 27
# Turing                                        27                 26
# App Academy                                   22                 20
# Hackbright Academy                            22                 19
# Bloc.io                                       21                 11
# Code Fellows                                  21                 15
# MakerSquare                                   20                 18
# Galvanize                                     20                 11
# New York Code + Design Academy                20                 14
# Coding Dojo                                   18                 11
# The Firehose Project                          16                 13
# Free Code Camp                                15                 14
# Epicodus                                      14                 11
# Dev Academy                                   13                 13
# Makers Academy                                12                 12
# Tech Talent South                             12                  8
# Coder Camps                                   11                  6

# %%
# Calculate percentage of eac bootcamp's students who are recommenders
merge_table["Percentage of recommendations"]=((merge_table["BootcampRecommend"]/merge_table["AttendedBootcamp"])*100).map("${:.2f}%".format)

merge_table
# Out:
#                                 AttendedBootcamp  BootcampRecommend  \
# BootcampName
# General Assembly                              90                 70
# Flatiron School                               54                 50
# Dev Bootcamp                                  48                 41
# The Iron Yard                                 40                 31
# Prime Digital Academy                         30                 25
# Hack Reactor                                  29                 27
# Turing                                        27                 26
# App Academy                                   22                 20
# Hackbright Academy                            22                 19
# Bloc.io                                       21                 11
# Code Fellows                                  21                 15
# MakerSquare                                   20                 18
# Galvanize                                     20                 11
# New York Code + Design Academy                20                 14
# Coding Dojo                                   18                 11
# The Firehose Project                          16                 13
# Free Code Camp                                15                 14
# Epicodus                                      14                 11
# Dev Academy                                   13                 13
# Makers Academy                                12                 12
# Tech Talent South                             12                  8
# Coder Camps                                   11                  6
#
#                                Percentage of recommendations
# BootcampName
# General Assembly                                     $77.78%
# Flatiron School                                      $92.59%
# Dev Bootcamp                                         $85.42%
# The Iron Yard                                        $77.50%
# Prime Digital Academy                                $83.33%
# Hack Reactor                                         $93.10%
# Turing                                               $96.30%
# App Academy                                          $90.91%
# Hackbright Academy                                   $86.36%
# Bloc.io                                              $52.38%
# Code Fellows                                         $71.43%
# MakerSquare                                          $90.00%
# Galvanize                                            $55.00%
# New York Code + Design Academy                       $70.00%
# Coding Dojo                                          $61.11%
# The Firehose Project                                 $81.25%
# Free Code Camp                                       $93.33%
# Epicodus                                             $78.57%
# Dev Academy                                         $100.00%
# Makers Academy                                      $100.00%
# Tech Talent South                                    $66.67%
# Coder Camps                                          $54.55%

# %%
# Export to excel and remove index

merge_table=merge_table.sort_values("Percentage of recommendations",ascending=False)
report=merge_table.reset_index()
report
# Out:
#                       BootcampName  AttendedBootcamp  BootcampRecommend  \
# 0                           Turing                27                 26
# 1                   Free Code Camp                15                 14
# 2                     Hack Reactor                29                 27
# 3                  Flatiron School                54                 50
# 4                      App Academy                22                 20
# 5                      MakerSquare                20                 18
# 6               Hackbright Academy                22                 19
# 7                     Dev Bootcamp                48                 41
# 8            Prime Digital Academy                30                 25
# 9             The Firehose Project                16                 13
# 10                        Epicodus                14                 11
# 11                General Assembly                90                 70
# 12                   The Iron Yard                40                 31
# 13                    Code Fellows                21                 15
# 14  New York Code + Design Academy                20                 14
# 15               Tech Talent South                12                  8
# 16                     Coding Dojo                18                 11
# 17                       Galvanize                20                 11
# 18                     Coder Camps                11                  6
# 19                         Bloc.io                21                 11
# 20                     Dev Academy                13                 13
# 21                  Makers Academy                12                 12
#
#    Percentage of recommendations
# 0                        $96.30%
# 1                        $93.33%
# 2                        $93.10%
# 3                        $92.59%
# 4                        $90.91%
# 5                        $90.00%
# 6                        $86.36%
# 7                        $85.42%
# 8                        $83.33%
# 9                        $81.25%
# 10                       $78.57%
# 11                       $77.78%
# 12                       $77.50%
# 13                       $71.43%
# 14                       $70.00%
# 15                       $66.67%
# 16                       $61.11%
# 17                       $55.00%
# 18                       $54.55%
# 19                       $52.38%
# 20                      $100.00%
# 21                      $100.00%

# %%
# Export to Excel
report.to_csv("output\BootcampOutputPart2.csv")
report
# Out:
#                       BootcampName  AttendedBootcamp  BootcampRecommend  \
# 0                           Turing                27                 26
# 1                   Free Code Camp                15                 14
# 2                     Hack Reactor                29                 27
# 3                  Flatiron School                54                 50
# 4                      App Academy                22                 20
# 5                      MakerSquare                20                 18
# 6               Hackbright Academy                22                 19
# 7                     Dev Bootcamp                48                 41
# 8            Prime Digital Academy                30                 25
# 9             The Firehose Project                16                 13
# 10                        Epicodus                14                 11
# 11                General Assembly                90                 70
# 12                   The Iron Yard                40                 31
# 13                    Code Fellows                21                 15
# 14  New York Code + Design Academy                20                 14
# 15               Tech Talent South                12                  8
# 16                     Coding Dojo                18                 11
# 17                       Galvanize                20                 11
# 18                     Coder Camps                11                  6
# 19                         Bloc.io                21                 11
# 20                     Dev Academy                13                 13
# 21                  Makers Academy                12                 12
#
#    Percentage of recommendations
# 0                        $96.30%
# 1                        $93.33%
# 2                        $93.10%
# 3                        $92.59%
# 4                        $90.91%
# 5                        $90.00%
# 6                        $86.36%
# 7                        $85.42%
# 8                        $83.33%
# 9                        $81.25%
# 10                       $78.57%
# 11                       $77.78%
# 12                       $77.50%
# 13                       $71.43%
# 14                       $70.00%
# 15                       $66.67%
# 16                       $61.11%
# 17                       $55.00%
# 18                       $54.55%
# 19                       $52.38%
# 20                      $100.00%
# 21                      $100.00%

# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from citipy import citipy

from config import api_key

# Import API key

# Incorporated citipy to determine city based on latitude and longitude

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)



# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

query_url
city="Arlington, Virginia"

response = requests.get(query_url + city).json()
#response["main"]["temp"]
query_url
response["dt"]
# Out:
# 1571690043

# %%
# set up lists to hold reponse info

citiesTemperature= pd.DataFrame(cities, columns=["Cities"])
citiesTemperature["Latitude"]=""
citiesTemperature["Longtitude"]=""
citiesTemperature["Temperature"]=""
citiesTemperature["Humidity"]=""
citiesTemperature["Wind speed"]=""
citiesTemperature["Cloudiness"]=""




citiesTemperature.head()
# Out:
#          Cities Latitude Longtitude Temperature Humidity Wind speed Cloudiness
# 0       chapais
# 1   songjianghe
# 2  puerto ayora
# 3    oranjestad
# 4     bathsheba

# %%
# Loop through the list of cities and perform a request for data on each

# call requests:
#response["coord"]["lon"]
#response["coord"]["lat"]
#response["name"]
#response["main"]["humidity"]
#response["wind"]["speed"]
#response["clouds"]["all"]
#response["dt"]

DateRetrieved= pd.to_datetime('today').strftime("%m/%d/%Y")

for index, row in citiesTemperature.iterrows():
        city = row['Cities']
    
        try:
            response = requests.get(query_url + city).json()
            tem=response['main']["temp_max"]
            weather= response["weather"][0]["description"]
            #temp.append(response['main']['temp'])
            citiesTemperature.loc[index, "Cities"] = response["name"]
            citiesTemperature.loc[index, "Latitude"] = response["coord"]["lat"]
            citiesTemperature.loc[index, "Longtitude"] = response["coord"]["lon"]
            citiesTemperature.loc[index, "Temperature"] = response['main']["temp_max"]
            citiesTemperature.loc[index, "Humidity"] = response["main"]["humidity"]
            citiesTemperature.loc[index, "Wind speed"] = response["wind"]["speed"]
            citiesTemperature.loc[index, "Cloudiness"] = response["clouds"]["all"]
            print(f"The max temperature of {city} today  is: {tem} and the weather is {weather}")

        except:
            #citiesTemperature.loc[index, "Cities"] = "No Values"
            #print(f"Missing Value")
            continue
# Out:
# The max temperature of Chapais today  is: 9 and the weather is overcast clouds
# The max temperature of Songjianghe today  is: 4.73 and the weather is clear sky
# The max temperature of Puerto Ayora today  is: 24 and the weather is overcast clouds
# The max temperature of Oranjestad today  is: 31 and the weather is few clouds
# The max temperature of Bathsheba today  is: 29 and the weather is few clouds
# The max temperature of Lebu today  is: 14 and the weather is scattered clouds
# The max temperature of Rikitea today  is: 21.67 and the weather is overcast clouds
# The max temperature of Tasiilaq today  is: -3 and the weather is light shower snow
# The max temperature of Hermanus today  is: 12.78 and the weather is broken clouds
# The max temperature of Zheleznodorozhnyy today  is: 9 and the weather is fog
# The max temperature of Georgetown today  is: 29 and the weather is light intensity shower rain
# The max temperature of Requena today  is: 16.67 and the weather is few clouds
# The max temperature of Butaritari today  is: 28.64 and the weather is light rain
# The max temperature of Suphan Buri today  is: 26.11 and the weather is broken clouds
# The max temperature of Ushuaia today  is: 15 and the weather is scattered clouds
# The max temperature of Itarema today  is: 24.6 and the weather is overcast clouds
# The max temperature of Barrow today  is: 15.19 and the weather is light rain
# The max temperature of Tuktoyaktuk today  is: -11 and the weather is scattered clouds
# The max temperature of Bluff today  is: 18.73 and the weather is clear sky
# The max temperature of Pevek today  is: -5.65 and the weather is broken clouds
# The max temperature of Hobart today  is: 12.22 and the weather is few clouds
# The max temperature of Bucak today  is: 20 and the weather is clear sky
# The max temperature of Kensington today  is: 14 and the weather is scattered clouds
# The max temperature of Nhulunbuy today  is: 25 and the weather is clear sky
# The max temperature of Hay River today  is: 1 and the weather is broken clouds
# The max temperature of Matadi today  is: 24.8 and the weather is light rain
# The max temperature of Carnarvon today  is: 10.47 and the weather is scattered clouds
# The max temperature of Athabasca today  is: 5.52 and the weather is broken clouds
# The max temperature of Namwala today  is: 23.58 and the weather is clear sky
# The max temperature of Klaksvik today  is: 9 and the weather is light rain
# The max temperature of Nikolskoye today  is: 5.56 and the weather is overcast clouds
# The max temperature of Bayangol today  is: -2.65 and the weather is snow
# The max temperature of Arraial do Cabo today  is: 22 and the weather is broken clouds
# The max temperature of Faanui today  is: 27.04 and the weather is light rain
# The max temperature of Mataura today  is: 6.11 and the weather is overcast clouds
# The max temperature of Leh today  is: -3.19 and the weather is clear sky
# The max temperature of Punta Arenas today  is: 13 and the weather is broken clouds
# The max temperature of La Romana today  is: 28 and the weather is light rain
# The max temperature of Portland today  is: 18 and the weather is clear sky
# The max temperature of Heihe today  is: -1 and the weather is clear sky
# The max temperature of Buchanan today  is: 26 and the weather is scattered clouds
# The max temperature of Strezhevoy today  is: -4 and the weather is overcast clouds
# The max temperature of Lagoa today  is: 15 and the weather is few clouds
# The max temperature of Ilulissat today  is: -7 and the weather is clear sky
# The max temperature of Henties Bay today  is: 16.67 and the weather is clear sky
# The max temperature of Atuona today  is: 25.97 and the weather is clear sky
# The max temperature of Ancud today  is: 11 and the weather is clear sky
# The max temperature of Busselton today  is: 15.56 and the weather is clear sky
# The max temperature of East London today  is: 16.06 and the weather is light rain
# The max temperature of Salekhard today  is: -6.45 and the weather is overcast clouds
# The max temperature of Torbay today  is: 8.89 and the weather is broken clouds
# The max temperature of Okhotsk today  is: -2.55 and the weather is light snow
# The max temperature of San Juan today  is: 28.04 and the weather is clear sky
# The max temperature of Los Llanos de Aridane today  is: 19 and the weather is broken clouds
# The max temperature of Kavieng today  is: 28.41 and the weather is overcast clouds
# The max temperature of Albany today  is: 17.22 and the weather is few clouds
# The max temperature of Vaini today  is: 20.12 and the weather is light rain
# The max temperature of Fortuna today  is: 22.22 and the weather is few clouds
# The max temperature of Port Alfred today  is: 15 and the weather is light rain
# The max temperature of Hasaki today  is: 16 and the weather is shower rain
# The max temperature of Pangkalanbuun today  is: 22.67 and the weather is overcast clouds
# The max temperature of Praia da Vitoria today  is: 18 and the weather is scattered clouds
# The max temperature of Talnakh today  is: -7 and the weather is broken clouds
# The max temperature of Belaya Gora today  is: -16.51 and the weather is scattered clouds
# The max temperature of Norman Wells today  is: -3 and the weather is light snow
# The max temperature of San Patricio today  is: 18.9 and the weather is light rain
# The max temperature of Sitka today  is: 17.22 and the weather is clear sky
# The max temperature of Mar del Plata today  is: 15.07 and the weather is clear sky
# The max temperature of Diphu today  is: 20.29 and the weather is light rain
# The max temperature of Trairi today  is: 24.9 and the weather is overcast clouds
# The max temperature of Chuy today  is: 12.74 and the weather is overcast clouds
# The max temperature of Winchester today  is: 11.67 and the weather is clear sky
# The max temperature of Port Said today  is: 26.91 and the weather is clear sky
# The max temperature of Khatanga today  is: -9.46 and the weather is light snow
# The max temperature of Aklavik today  is: -6 and the weather is overcast clouds
# The max temperature of Kytmanovo today  is: -11.29 and the weather is clear sky
# The max temperature of Coihaique today  is: 12 and the weather is few clouds
# The max temperature of Sheregesh today  is: -13.18 and the weather is clear sky
# The max temperature of Castro today  is: 11 and the weather is clear sky
# The max temperature of Christchurch today  is: 13.89 and the weather is clear sky
# The max temperature of Kamina today  is: 19.69 and the weather is broken clouds
# The max temperature of Fatehpur today  is: 23.6 and the weather is clear sky
# The max temperature of Cananea today  is: 26.67 and the weather is clear sky
# The max temperature of Poya today  is: 22.95 and the weather is overcast clouds
# The max temperature of Rio das Ostras today  is: 22 and the weather is overcast clouds
# The max temperature of Pisco today  is: 22 and the weather is few clouds
# The max temperature of Karratha today  is: 26.85 and the weather is clear sky
# The max temperature of Lompoc today  is: 33.33 and the weather is clear sky
# The max temperature of Zonhoven today  is: 13.33 and the weather is overcast clouds
# The max temperature of Airai today  is: 18.78 and the weather is few clouds
# The max temperature of Terrace Bay today  is: 11 and the weather is overcast clouds
# The max temperature of Mahebourg today  is: 24 and the weather is shower rain
# The max temperature of Dauphin today  is: 7 and the weather is broken clouds
# The max temperature of Sidney today  is: 10 and the weather is clear sky
# The max temperature of Sungaipenuh today  is: 16.74 and the weather is broken clouds
# The max temperature of Hilo today  is: 27 and the weather is overcast clouds
# The max temperature of Vechta today  is: 13.33 and the weather is broken clouds
# The max temperature of Caravelas today  is: 23.08 and the weather is overcast clouds
# The max temperature of Yerbogachen today  is: -7.41 and the weather is overcast clouds
# The max temperature of Haines Junction today  is: -4.52 and the weather is overcast clouds
# The max temperature of Saint-Philippe today  is: 16.11 and the weather is clear sky
# The max temperature of Sotnikovo today  is: -10 and the weather is broken clouds
# The max temperature of Alto Araguaia today  is: 21.07 and the weather is light rain
# The max temperature of College today  is: 1.11 and the weather is scattered clouds
# The max temperature of Victoria today  is: 27 and the weather is broken clouds
# The max temperature of Dunedin today  is: 12.22 and the weather is scattered clouds
# The max temperature of Flinders today  is: 15 and the weather is clear sky
# The max temperature of Bredasdorp today  is: 11.67 and the weather is overcast clouds
# The max temperature of Hithadhoo today  is: 27.07 and the weather is clear sky
# The max temperature of Qaanaaq today  is: -14.84 and the weather is clear sky
# The max temperature of Cape Town today  is: 13.89 and the weather is clear sky
# The max temperature of Kapaa today  is: 28 and the weather is scattered clouds
# The max temperature of Lagos today  is: 27 and the weather is few clouds
# The max temperature of Rosarito today  is: 28 and the weather is fog
# The max temperature of Ostrovnoy today  is: -7.32 and the weather is overcast clouds
# The max temperature of Saurimo today  is: 19.07 and the weather is overcast clouds
# The max temperature of Tiarei today  is: 29 and the weather is shower rain
# The max temperature of Seoul today  is: 12 and the weather is mist
# The max temperature of Atar today  is: 28.8 and the weather is clear sky
# The max temperature of General Roca today  is: 19 and the weather is clear sky
# The max temperature of Road Town today  is: 31 and the weather is scattered clouds
# The max temperature of Iquitos today  is: 32 and the weather is broken clouds
# The max temperature of Tuatapere today  is: 6.11 and the weather is light rain
# The max temperature of The Valley today  is: 31 and the weather is scattered clouds
# The max temperature of Mezen today  is: -1.15 and the weather is broken clouds
# The max temperature of Hellvik today  is: 9 and the weather is broken clouds
# The max temperature of Sivas today  is: 7 and the weather is scattered clouds
# The max temperature of Cidreira today  is: 17.21 and the weather is light rain
# The max temperature of Grindavik today  is: 2 and the weather is broken clouds
# The max temperature of Werda today  is: 20.89 and the weather is clear sky
# The max temperature of Iqaluit today  is: -1 and the weather is broken clouds
# The max temperature of Alvin today  is: 27.22 and the weather is clear sky
# The max temperature of Carbonia today  is: 23 and the weather is broken clouds
# The max temperature of Puro today  is: 26.11 and the weather is clear sky
# The max temperature of Boa Vista today  is: 32 and the weather is scattered clouds
# The max temperature of Salto today  is: 24.44 and the weather is moderate rain
# The max temperature of Dingle today  is: 23.55 and the weather is clear sky
# The max temperature of Kieta today  is: 27.4 and the weather is broken clouds
# The max temperature of Vostok today  is: -0.45 and the weather is clear sky
# The max temperature of Kaitangata today  is: 8.41 and the weather is light rain
# The max temperature of Ponta do Sol today  is: 22.92 and the weather is overcast clouds
# The max temperature of Bethel today  is: 0 and the weather is light rain
# The max temperature of Kodiak today  is: 13 and the weather is overcast clouds
# The max temperature of Kerema today  is: 23.79 and the weather is light rain
# The max temperature of Lensk today  is: -8.01 and the weather is overcast clouds
# The max temperature of Chilca today  is: 20.56 and the weather is shower rain
# The max temperature of Labuhan today  is: 21.67 and the weather is overcast clouds
# The max temperature of Mirabad today  is: 18.08 and the weather is scattered clouds
# The max temperature of Thompson today  is: 5 and the weather is scattered clouds
# The max temperature of Rybnaya Sloboda today  is: 12 and the weather is light intensity shower rain
# The max temperature of Dikson today  is: -2.58 and the weather is overcast clouds
# The max temperature of Tazovskiy today  is: -8.18 and the weather is broken clouds
# The max temperature of Jamestown today  is: 15.2 and the weather is overcast clouds
# The max temperature of Cherskiy today  is: -18.01 and the weather is broken clouds
# The max temperature of Piacabucu today  is: 24.78 and the weather is clear sky
# The max temperature of Jiuquan today  is: 4.98 and the weather is clear sky
# The max temperature of Sangar today  is: -9.24 and the weather is clear sky
# The max temperature of Soyo today  is: 25.77 and the weather is overcast clouds
# The max temperature of Vila Franca do Campo today  is: 18 and the weather is few clouds
# The max temperature of Dabat today  is: 14.18 and the weather is scattered clouds
# The max temperature of Berlevag today  is: 0 and the weather is scattered clouds
# The max temperature of Skjervoy today  is: 0 and the weather is broken clouds
# The max temperature of Upernavik today  is: -11.82 and the weather is clear sky
# The max temperature of Lunenburg today  is: 13.89 and the weather is scattered clouds
# The max temperature of Fort Nelson today  is: 2 and the weather is few clouds
# The max temperature of Nouakchott today  is: 25 and the weather is clear sky
# The max temperature of Yulara today  is: 17 and the weather is clear sky
# The max temperature of Sao Felix do Xingu today  is: 29.64 and the weather is overcast clouds
# The max temperature of Madison today  is: 18 and the weather is scattered clouds
# The max temperature of Bubaque today  is: 27.88 and the weather is overcast clouds
# The max temperature of Tsivilsk today  is: 11 and the weather is light intensity shower rain
# The max temperature of Samarai today  is: 24.54 and the weather is light rain
# The max temperature of Scarborough today  is: 9.44 and the weather is clear sky
# The max temperature of Miles City today  is: 12.22 and the weather is scattered clouds
# The max temperature of Omboue today  is: 23.41 and the weather is light rain
# The max temperature of Port Macquarie today  is: 15.56 and the weather is clear sky
# The max temperature of Shimoda today  is: 17.78 and the weather is heavy intensity rain
# The max temperature of Margate today  is: 12.22 and the weather is few clouds
# The max temperature of Pacific Grove today  is: 28.89 and the weather is clear sky
# The max temperature of Bradford today  is: 9 and the weather is scattered clouds
# The max temperature of Viedma today  is: 11.37 and the weather is moderate rain
# The max temperature of Rio Grande today  is: 17 and the weather is overcast clouds
# The max temperature of Anadyr today  is: -7 and the weather is scattered clouds
# The max temperature of Pangnirtung today  is: -3 and the weather is few clouds
# The max temperature of Vila Velha today  is: 28 and the weather is overcast clouds
# The max temperature of Masakin today  is: 19.87 and the weather is clear sky
# The max temperature of Pundaguitan today  is: 27.6 and the weather is moderate rain
# The max temperature of Verkh-Usugli today  is: -8.43 and the weather is clear sky
# The max temperature of Jiancheng today  is: 18.89 and the weather is mist
# The max temperature of Yumen today  is: 6.47 and the weather is clear sky
# The max temperature of Sabha today  is: 24.68 and the weather is scattered clouds
# The max temperature of Cervo today  is: 20 and the weather is broken clouds
# The max temperature of Tautira today  is: 29 and the weather is shower rain
# The max temperature of Madimba today  is: 25 and the weather is thunderstorm
# The max temperature of Okha today  is: 5.5 and the weather is light rain
# The max temperature of Raudeberg today  is: 8 and the weather is moderate rain
# The max temperature of Roros today  is: 1 and the weather is light snow
# The max temperature of Akdepe today  is: 9 and the weather is clear sky
# The max temperature of Souillac today  is: 12.22 and the weather is clear sky
# The max temperature of Katsuura today  is: 19 and the weather is broken clouds
# The max temperature of Cap Malheureux today  is: 24 and the weather is shower rain
# The max temperature of Ulaanbaatar today  is: -9 and the weather is scattered clouds
# The max temperature of Cockburn Town today  is: 30 and the weather is scattered clouds
# The max temperature of Saldanha today  is: 9.33 and the weather is light rain
# The max temperature of Palmeirais today  is: 30.27 and the weather is broken clouds
# The max temperature of Bethlehem today  is: 20 and the weather is clear sky
# The max temperature of Nador today  is: 16 and the weather is light rain
# The max temperature of Belyy Yar today  is: -5 and the weather is scattered clouds
# The max temperature of Bud today  is: 10 and the weather is light rain
# The max temperature of Svetlogorsk today  is: 3 and the weather is overcast clouds
# The max temperature of Provideniya today  is: 1 and the weather is broken clouds
# The max temperature of Arawa today  is: 22.65 and the weather is scattered clouds
# The max temperature of Praya today  is: 25 and the weather is few clouds
# The max temperature of Puerto del Rosario today  is: 21 and the weather is few clouds
# The max temperature of Fayaoue today  is: 23.66 and the weather is scattered clouds
# The max temperature of Healesville today  is: 12.78 and the weather is overcast clouds
# The max temperature of Hovd today  is: 8.33 and the weather is broken clouds
# The max temperature of Gavle today  is: 6.11 and the weather is overcast clouds
# The max temperature of Rosetta today  is: 25 and the weather is scattered clouds
# The max temperature of Nemuro today  is: 13.27 and the weather is overcast clouds
# The max temperature of Batagay-Alyta today  is: -13.45 and the weather is few clouds
# The max temperature of Longyearbyen today  is: -9 and the weather is broken clouds
# The max temperature of Lata today  is: -4.13 and the weather is clear sky
# The max temperature of Saint Lawrence today  is: 20.56 and the weather is clear sky
# The max temperature of Ribeira Grande today  is: 19 and the weather is scattered clouds
# The max temperature of Govlyar today  is: 13 and the weather is scattered clouds
# The max temperature of Port Elizabeth today  is: 21.11 and the weather is clear sky
# The max temperature of Alamosa today  is: 8 and the weather is scattered clouds
# The max temperature of Tiksi today  is: -13.53 and the weather is overcast clouds
# The max temperature of Longhua today  is: 16.72 and the weather is light rain
# The max temperature of Montero today  is: 27 and the weather is broken clouds
# The max temperature of Yellowknife today  is: -2 and the weather is overcast clouds
# The max temperature of Srednekolymsk today  is: -15.44 and the weather is overcast clouds
# The max temperature of Bundaberg today  is: 19.44 and the weather is clear sky
# The max temperature of Balkanabat today  is: 13.91 and the weather is clear sky
# The max temperature of New Norfolk today  is: 12.22 and the weather is few clouds
# The max temperature of Ranong today  is: 26.44 and the weather is overcast clouds
# The max temperature of Kruisfontein today  is: 10.92 and the weather is light rain
# The max temperature of Chokurdakh today  is: -15.47 and the weather is overcast clouds
# The max temperature of Sudak today  is: 11.13 and the weather is clear sky
# The max temperature of Sobolevo today  is: 11.27 and the weather is broken clouds
# The max temperature of Hami today  is: 8.07 and the weather is broken clouds
# The max temperature of Itoman today  is: 23 and the weather is light intensity shower rain
# The max temperature of Monrovia today  is: 26 and the weather is scattered clouds
# The max temperature of Narsaq today  is: 3 and the weather is clear sky
# The max temperature of Tomatlan today  is: 23.97 and the weather is overcast clouds
# The max temperature of Beloha today  is: 22.8 and the weather is clear sky
# The max temperature of Huarmey today  is: 21.39 and the weather is broken clouds
# The max temperature of Bambous Virieux today  is: 24 and the weather is shower rain
# The max temperature of Dabola today  is: 22.64 and the weather is light rain
# The max temperature of Fairbanks today  is: 1.11 and the weather is scattered clouds
# The max temperature of Mayo today  is: 0 and the weather is broken clouds
# The max temperature of Eyl today  is: 27.24 and the weather is clear sky
# The max temperature of Geraldton today  is: 7 and the weather is overcast clouds
# The max temperature of Chongwe today  is: 23.15 and the weather is broken clouds
# The max temperature of Sheridan today  is: 12.78 and the weather is broken clouds
# The max temperature of Zhanakorgan today  is: 7.52 and the weather is clear sky
# The max temperature of Honningsvag today  is: 0 and the weather is broken clouds
# The max temperature of Mehamn today  is: 0 and the weather is light shower snow
# The max temperature of Wanning today  is: 12.78 and the weather is mist
# The max temperature of Ittiri today  is: 21 and the weather is few clouds
# The max temperature of Xining today  is: 3.59 and the weather is clear sky
# The max temperature of Inongo today  is: 23.34 and the weather is overcast clouds
# The max temperature of Ferrol today  is: 10 and the weather is few clouds
# The max temperature of Evansville today  is: 20 and the weather is clear sky
# The max temperature of Gawler today  is: 17.22 and the weather is broken clouds
# The max temperature of Tessalit today  is: 31.67 and the weather is overcast clouds
# The max temperature of Constitucion today  is: 26 and the weather is broken clouds
# The max temperature of Sovetskiy today  is: 9.32 and the weather is moderate rain
# The max temperature of Roebourne today  is: 25.77 and the weather is clear sky
# The max temperature of Bindi today  is: 31.52 and the weather is scattered clouds
# The max temperature of Tolmezzo today  is: 16.67 and the weather is scattered clouds
# The max temperature of Dehui today  is: 3 and the weather is smoke
# The max temperature of Maxixe today  is: 24.54 and the weather is clear sky
# The max temperature of Nishihara today  is: 16.67 and the weather is heavy intensity rain
# The max temperature of Yar-Sale today  is: -7.19 and the weather is few clouds
# The max temperature of Miranda today  is: 25.47 and the weather is light rain
# The max temperature of Prince Albert today  is: 6 and the weather is broken clouds
# The max temperature of Namibe today  is: 20.76 and the weather is overcast clouds
# The max temperature of Ullapool today  is: 10.56 and the weather is overcast clouds
# The max temperature of Nadym today  is: -7.39 and the weather is few clouds
# The max temperature of Champerico today  is: 32 and the weather is scattered clouds
# The max temperature of Ozernovskiy today  is: 3.48 and the weather is overcast clouds
# The max temperature of Avarua today  is: 26 and the weather is clear sky
# The max temperature of Pauini today  is: 22.92 and the weather is light rain
# The max temperature of Jawor today  is: 12.78 and the weather is overcast clouds
# The max temperature of Saskylakh today  is: -11.25 and the weather is overcast clouds
# The max temperature of Tsabong today  is: 20.61 and the weather is clear sky
# The max temperature of Puerto Escondido today  is: 31 and the weather is few clouds
# The max temperature of Micheweni today  is: 26.63 and the weather is light rain
# The max temperature of Padang today  is: 19.34 and the weather is overcast clouds
# The max temperature of Bethanien today  is: 20.55 and the weather is clear sky
# The max temperature of Mount Gambier today  is: 5 and the weather is broken clouds
# The max temperature of Praia today  is: 26 and the weather is few clouds
# The max temperature of Matagami today  is: 21.12 and the weather is scattered clouds
# The max temperature of Hervey Bay today  is: 19.44 and the weather is scattered clouds
# The max temperature of Diapaga today  is: 27.42 and the weather is clear sky
# The max temperature of Waidhofen today  is: 12.78 and the weather is fog
# The max temperature of Nanortalik today  is: 3.4 and the weather is few clouds
# The max temperature of Maba today  is: 13.61 and the weather is broken clouds
# The max temperature of Sechura today  is: 17.44 and the weather is scattered clouds
# The max temperature of Bontang today  is: 25.12 and the weather is broken clouds
# The max temperature of Udupi today  is: 24 and the weather is mist
# The max temperature of Lasa today  is: 21 and the weather is clear sky
# The max temperature of San Pedro today  is: 22.22 and the weather is clear sky
# The max temperature of Fukue today  is: 17 and the weather is light intensity shower rain
# The max temperature of Otane today  is: 10.56 and the weather is few clouds
# The max temperature of Barguzin today  is: -8.85 and the weather is clear sky
# The max temperature of Laukaa today  is: 0.56 and the weather is overcast clouds
# The max temperature of Houston today  is: 27.22 and the weather is clear sky
# The max temperature of Kalmunai today  is: 26.28 and the weather is moderate rain
# The max temperature of Kassala today  is: 30.09 and the weather is clear sky
# The max temperature of Solwezi today  is: 20.02 and the weather is few clouds
# The max temperature of Kiama today  is: 15 and the weather is clear sky
# The max temperature of Ixtapa today  is: 27.78 and the weather is overcast clouds
# The max temperature of Haapiti today  is: 29 and the weather is shower rain
# The max temperature of Inhambane today  is: 24.54 and the weather is clear sky
# The max temperature of Jalu today  is: 21.61 and the weather is clear sky
# The max temperature of Luderitz today  is: 17 and the weather is clear sky
# The max temperature of Asosa today  is: 18.4 and the weather is overcast clouds
# The max temperature of Neryungri today  is: -5.01 and the weather is light snow
# The max temperature of Pochutla today  is: 31.11 and the weather is broken clouds
# The max temperature of Aksehir today  is: 14.36 and the weather is light rain
# The max temperature of Saraza today  is: 29.18 and the weather is overcast clouds
# The max temperature of Coahuayana today  is: 28.09 and the weather is broken clouds
# The max temperature of Port Lincoln today  is: 15.42 and the weather is clear sky
# The max temperature of Surt today  is: 20.63 and the weather is clear sky
# The max temperature of Sukhobuzimskoye today  is: -6 and the weather is overcast clouds
# The max temperature of Levelland today  is: 21 and the weather is few clouds
# The max temperature of Severo-Kurilsk today  is: 1.09 and the weather is overcast clouds
# The max temperature of Flin Flon today  is: 4 and the weather is broken clouds
# The max temperature of Yaan today  is: 23.93 and the weather is overcast clouds
# The max temperature of Farah today  is: 15.65 and the weather is broken clouds
# The max temperature of Canutama today  is: 27.35 and the weather is overcast clouds
# The max temperature of Shingu today  is: 19.98 and the weather is light rain
# The max temperature of Ambovombe today  is: 22.83 and the weather is clear sky
# The max temperature of Gombong today  is: 22.97 and the weather is overcast clouds
# The max temperature of Kavaratti today  is: 26.18 and the weather is light rain
# The max temperature of Navahrudak today  is: 12.24 and the weather is broken clouds
# The max temperature of Virginia Beach today  is: 16.67 and the weather is overcast clouds
# The max temperature of Poum today  is: 12.28 and the weather is clear sky
# The max temperature of Newport today  is: 10.56 and the weather is broken clouds
# The max temperature of Tralee today  is: 25 and the weather is clear sky
# The max temperature of Havelock today  is: 19 and the weather is overcast clouds
# The max temperature of Umm Lajj today  is: 24.53 and the weather is overcast clouds
# The max temperature of Port Hedland today  is: 27 and the weather is broken clouds
# The max temperature of Abu Samrah today  is: 19.78 and the weather is light rain
# The max temperature of Belem today  is: 27.35 and the weather is overcast clouds
# The max temperature of Mangrol today  is: 21.7 and the weather is scattered clouds
# The max temperature of Coruripe today  is: 25.03 and the weather is clear sky
# The max temperature of Byron Bay today  is: 22.78 and the weather is scattered clouds
# The max temperature of La Ronge today  is: 4 and the weather is broken clouds
# The max temperature of Ilula today  is: 21 and the weather is clear sky
# The max temperature of Esperance today  is: 11 and the weather is scattered clouds
# The max temperature of Kimberley today  is: 17 and the weather is clear sky
# The max temperature of Takoradi today  is: 25.49 and the weather is clear sky
# The max temperature of Nelson Bay today  is: 17.78 and the weather is few clouds
# The max temperature of Alofi today  is: 26 and the weather is broken clouds
# The max temperature of Narrabri today  is: 17.78 and the weather is clear sky
# The max temperature of Yanggu today  is: 11.81 and the weather is clear sky
# The max temperature of Marzuq today  is: 20.78 and the weather is clear sky
# The max temperature of Guerrero Negro today  is: 32.34 and the weather is clear sky
# The max temperature of Kutum today  is: 26.75 and the weather is broken clouds
# The max temperature of Ajdabiya today  is: 22.03 and the weather is clear sky
# The max temperature of Makueni today  is: 19.65 and the weather is clear sky
# The max temperature of Yankton today  is: 6.67 and the weather is moderate rain
# The max temperature of Husavik today  is: 6.11 and the weather is overcast clouds
# The max temperature of Beringovskiy today  is: -4.53 and the weather is broken clouds
# The max temperature of Cuambog today  is: 26 and the weather is broken clouds
# The max temperature of Lorengau today  is: 29.03 and the weather is overcast clouds
# The max temperature of Kathmandu today  is: 14 and the weather is few clouds
# The max temperature of Batagay today  is: -14.71 and the weather is clear sky
# The max temperature of Huilong today  is: 15.87 and the weather is moderate rain
# The max temperature of Homer today  is: 6 and the weather is broken clouds
# The max temperature of Zhanaozen today  is: 10.34 and the weather is clear sky
# The max temperature of Cabo San Lucas today  is: 30.56 and the weather is few clouds
# The max temperature of Gari today  is: 0.8 and the weather is overcast clouds
# The max temperature of Nuuk today  is: 2 and the weather is clear sky
# The max temperature of Matara today  is: 15.73 and the weather is light rain
# The max temperature of Touros today  is: 27 and the weather is scattered clouds
# The max temperature of San Juan del Parana today  is: 20 and the weather is broken clouds
# The max temperature of Puerto Maldonado today  is: 31.52 and the weather is light rain
# The max temperature of Mombasa today  is: 23.51 and the weather is broken clouds
# The max temperature of Comodoro Rivadavia today  is: 17 and the weather is scattered clouds
# The max temperature of Te Anau today  is: 4.17 and the weather is light rain
# The max temperature of San Quintin today  is: 21.67 and the weather is clear sky
# The max temperature of Gobabis today  is: 28 and the weather is clear sky
# The max temperature of Ailigandi today  is: 26.84 and the weather is moderate rain
# The max temperature of Faya today  is: 18 and the weather is clear sky
# The max temperature of Antalaha today  is: 24.4 and the weather is broken clouds
# The max temperature of Ojinaga today  is: 27 and the weather is clear sky
# The max temperature of Codrington today  is: 16.67 and the weather is scattered clouds
# The max temperature of Luancheng today  is: 9 and the weather is mist
# The max temperature of Vrangel today  is: 12.76 and the weather is clear sky
# The max temperature of Bonavista today  is: 7.22 and the weather is broken clouds
# The max temperature of Necochea today  is: 15.56 and the weather is light rain
# The max temperature of Maceio today  is: 26 and the weather is clear sky
# The max temperature of Mayor Pablo Lagerenza today  is: 28.87 and the weather is scattered clouds
# The max temperature of Agutaya today  is: 28.52 and the weather is light rain
# The max temperature of Tecoanapa today  is: 30 and the weather is scattered clouds
# The max temperature of Malanje today  is: 19.61 and the weather is light rain
# The max temperature of Saint Anthony today  is: 10 and the weather is overcast clouds
# The max temperature of Bulnes today  is: 20 and the weather is overcast clouds
# The max temperature of Mahibadhoo today  is: 28.05 and the weather is overcast clouds
# The max temperature of Kochinda today  is: 20.97 and the weather is few clouds
# The max temperature of Harper today  is: 27.78 and the weather is clear sky
# The max temperature of Leningradskiy today  is: -2.63 and the weather is light snow
# The max temperature of Impfondo today  is: 21.78 and the weather is overcast clouds
# The max temperature of Doha today  is: 30 and the weather is clear sky
# The max temperature of Beira today  is: 11.11 and the weather is few clouds
# The max temperature of Tutoia today  is: 29 and the weather is few clouds
# The max temperature of Pandan today  is: 27.6 and the weather is clear sky
# The max temperature of Ostrogozhsk today  is: 12.14 and the weather is overcast clouds
# The max temperature of Goderich today  is: 17.78 and the weather is overcast clouds
# The max temperature of Chulym today  is: -5.18 and the weather is scattered clouds
# The max temperature of Zhadovka today  is: 11.3 and the weather is overcast clouds
# The max temperature of Iwanai today  is: 7.94 and the weather is overcast clouds
# The max temperature of Xuanhua today  is: 7.13 and the weather is clear sky
# The max temperature of Luganville today  is: 27 and the weather is broken clouds
# The max temperature of Santa Cruz de la Palma today  is: 19 and the weather is broken clouds
# The max temperature of Statesboro today  is: 28 and the weather is broken clouds
# The max temperature of Manicore today  is: 27 and the weather is thunderstorm
# The max temperature of Solnechnyy today  is: -0.43 and the weather is clear sky
# The max temperature of Ziro today  is: 13.19 and the weather is broken clouds
# The max temperature of Camacha today  is: 19 and the weather is scattered clouds
# The max temperature of Andilamena today  is: 16.39 and the weather is clear sky
# The max temperature of Tilichiki today  is: -11.13 and the weather is broken clouds
# The max temperature of Kaseda today  is: 18.69 and the weather is overcast clouds
# The max temperature of Launceston today  is: 10 and the weather is clear sky
# The max temperature of Dire today  is: 14 and the weather is scattered clouds
# The max temperature of Mwinilunga today  is: 19.83 and the weather is scattered clouds
# The max temperature of Egvekinot today  is: -8.3 and the weather is overcast clouds
# The max temperature of Mandalgovi today  is: 1.73 and the weather is few clouds
# The max temperature of Salalah today  is: 28 and the weather is overcast clouds
# The max temperature of Muros today  is: 13.33 and the weather is clear sky
# The max temperature of Nashville today  is: 18 and the weather is light rain
# The max temperature of Chegdomyn today  is: -0.43 and the weather is scattered clouds
# The max temperature of Erdaojiang today  is: 6 and the weather is broken clouds
# The max temperature of Saint-Augustin today  is: 15.56 and the weather is broken clouds
# The max temperature of Sacama today  is: 28 and the weather is broken clouds
# The max temperature of Lac du Bonnet today  is: 5.56 and the weather is light rain
# The max temperature of Lavrentiya today  is: 0.31 and the weather is overcast clouds
# The max temperature of Kloulklubed today  is: 28.69 and the weather is light rain
# The max temperature of Jiblah today  is: 17.79 and the weather is clear sky
# The max temperature of Bam today  is: 21.24 and the weather is clear sky
# The max temperature of Seda today  is: 13 and the weather is overcast clouds
# The max temperature of Acapulco today  is: 30 and the weather is scattered clouds
# The max temperature of Fuyang today  is: 17.61 and the weather is overcast clouds
# The max temperature of Alcaniz today  is: 11.55 and the weather is overcast clouds
# The max temperature of Kukuna today  is: 27 and the weather is broken clouds
# The max temperature of Port Augusta today  is: 16.67 and the weather is broken clouds
# The max temperature of Deputatskiy today  is: -13.7 and the weather is overcast clouds
# The max temperature of Alta Floresta today  is: 30 and the weather is shower rain
# The max temperature of Coquimbo today  is: 19 and the weather is overcast clouds
# The max temperature of Porto Novo today  is: 20 and the weather is broken clouds
# The max temperature of Shenjiamen today  is: 20.4 and the weather is broken clouds
# The max temperature of Dandong today  is: 13.92 and the weather is scattered clouds
# The max temperature of Najran today  is: 21 and the weather is clear sky
# The max temperature of Otavi today  is: 26.52 and the weather is clear sky
# The max temperature of Ambilobe today  is: 23.9 and the weather is overcast clouds
# The max temperature of Maglajani today  is: 14 and the weather is clear sky
# The max temperature of Kahului today  is: 32 and the weather is few clouds
# The max temperature of Krasnyy Yar today  is: 9.71 and the weather is scattered clouds
# The max temperature of Turka today  is: 2 and the weather is clear sky
# The max temperature of Inuvik today  is: -6 and the weather is light snow
# The max temperature of Tansen today  is: 14.25 and the weather is clear sky
# The max temperature of Isangel today  is: 22.98 and the weather is light rain
# The max temperature of Cururupu today  is: 26.78 and the weather is overcast clouds
# The max temperature of Vyazemskiy today  is: 2.22 and the weather is clear sky
# The max temperature of Gebre Guracha today  is: 14.57 and the weather is broken clouds
# The max temperature of Raub today  is: 21.93 and the weather is broken clouds
# The max temperature of Karpathos today  is: 22 and the weather is light rain
# The max temperature of Sao Joao da Barra today  is: 21 and the weather is overcast clouds
# The max temperature of Tanete today  is: 22.65 and the weather is scattered clouds
# The max temperature of Suarez today  is: 28 and the weather is broken clouds
# The max temperature of Dawei today  is: 27.11 and the weather is broken clouds
# The max temperature of Kadoma today  is: 18 and the weather is light rain
# The max temperature of Ketchikan today  is: 7 and the weather is light rain
# The max temperature of Arlit today  is: 34.51 and the weather is overcast clouds
# The max temperature of Gizo today  is: 23.33 and the weather is clear sky
# The max temperature of Redlands today  is: 36.11 and the weather is clear sky
# The max temperature of San Ramon today  is: 24 and the weather is broken clouds
# The max temperature of Shelburne today  is: 16.11 and the weather is clear sky
# The max temperature of Grandview today  is: 14.44 and the weather is few clouds
# The max temperature of Huntsville today  is: 20 and the weather is heavy intensity rain
# The max temperature of Gushikawa today  is: 23 and the weather is light intensity shower rain
# The max temperature of Kajiado today  is: 18 and the weather is clear sky
# The max temperature of Ahuimanu today  is: 31.11 and the weather is scattered clouds
# The max temperature of Riga today  is: 6.11 and the weather is fog
# The max temperature of Polson today  is: 8 and the weather is overcast clouds
# The max temperature of Nantucket today  is: 14.44 and the weather is overcast clouds
# The max temperature of Maunabo today  is: 31 and the weather is scattered clouds
# The max temperature of Aripuana today  is: 27.84 and the weather is overcast clouds
# The max temperature of Cabra today  is: 13.33 and the weather is clear sky
# The max temperature of Longonjo today  is: 19.53 and the weather is broken clouds
# The max temperature of Ulladulla today  is: 13.33 and the weather is clear sky
# The max temperature of Verkhnevilyuysk today  is: -4.84 and the weather is overcast clouds
# The max temperature of Talcahuano today  is: 18 and the weather is overcast clouds
# The max temperature of Totness today  is: 26.67 and the weather is light intensity drizzle
# The max temperature of Kondagaon today  is: 19.47 and the weather is scattered clouds
# The max temperature of Coxim today  is: 31.91 and the weather is scattered clouds
# The max temperature of Hutchinson today  is: 18.33 and the weather is heavy intensity rain
# The max temperature of Amla today  is: 19.77 and the weather is broken clouds
# The max temperature of Malyye Derbety today  is: 11.14 and the weather is clear sky
# The max temperature of Alugan today  is: 25.9 and the weather is light rain
# The max temperature of Deder today  is: 18.11 and the weather is clear sky
# The max temperature of Aksu today  is: -11 and the weather is broken clouds
# The max temperature of Usakos today  is: 21.18 and the weather is clear sky
# The max temperature of Arzachena today  is: 21 and the weather is broken clouds
# The max temperature of Poplar Bluff today  is: 22 and the weather is scattered clouds
# The max temperature of Ornskoldsvik today  is: 3 and the weather is few clouds
# The max temperature of Paamiut today  is: 3.12 and the weather is clear sky
# The max temperature of Andros Town today  is: 30 and the weather is scattered clouds
# The max temperature of Kontagora today  is: 25.44 and the weather is overcast clouds
# The max temperature of Evensk today  is: -9.58 and the weather is clear sky
# The max temperature of Linares today  is: 18.93 and the weather is overcast clouds
# The max temperature of Turinskaya Sloboda today  is: -0.27 and the weather is broken clouds
# The max temperature of Salta today  is: 29 and the weather is few clouds
# The max temperature of Colares today  is: 16.67 and the weather is few clouds
# The max temperature of Dover today  is: 21.11 and the weather is clear sky
# The max temperature of Saint-Pierre today  is: 10 and the weather is scattered clouds
# The max temperature of High Rock today  is: 31 and the weather is broken clouds
# The max temperature of Hambantota today  is: 26.52 and the weather is overcast clouds
# The max temperature of Meitingen today  is: 12.22 and the weather is overcast clouds
# The max temperature of Saint George today  is: 16 and the weather is clear sky
# The max temperature of Nyrob today  is: 7.58 and the weather is moderate rain
# The max temperature of Taoudenni today  is: 34.05 and the weather is scattered clouds
# The max temperature of Limbang today  is: 27 and the weather is broken clouds
# The max temperature of Luwuk today  is: 26.35 and the weather is scattered clouds
# The max temperature of Port Blair today  is: 28.49 and the weather is overcast clouds
# The max temperature of Stromness today  is: 23 and the weather is broken clouds
# The max temperature of Sao Filipe today  is: 25.19 and the weather is clear sky
# The max temperature of Durazno today  is: 16 and the weather is broken clouds
# The max temperature of Great Falls today  is: 11 and the weather is broken clouds
# The max temperature of Orlik today  is: 13.33 and the weather is mist
# The max temperature of Grand Gaube today  is: 24 and the weather is shower rain
# The max temperature of Sombor today  is: 14 and the weather is scattered clouds
# The max temperature of Redwater today  is: 7.22 and the weather is overcast clouds
# The max temperature of Banda Aceh today  is: 22.99 and the weather is overcast clouds
# The max temperature of Broome today  is: 11.11 and the weather is broken clouds
# The max temperature of Port Hardy today  is: 9 and the weather is light rain
# The max temperature of Calvinia today  is: 11.54 and the weather is clear sky
# The max temperature of Slave Lake today  is: 1 and the weather is overcast clouds
# The max temperature of Botwood today  is: 8.33 and the weather is light intensity shower rain
# The max temperature of Dongsheng today  is: 19.14 and the weather is overcast clouds
# The max temperature of Bilma today  is: 29.78 and the weather is clear sky
# The max temperature of Hollola today  is: 1.67 and the weather is overcast clouds
# The max temperature of Prince Rupert today  is: 10 and the weather is light rain
# The max temperature of Puerto Carreno today  is: 34 and the weather is scattered clouds
# The max temperature of Changping today  is: 15.56 and the weather is clear sky
# The max temperature of Valparaiso today  is: 20 and the weather is light rain
# The max temperature of Adre today  is: 28.03 and the weather is overcast clouds
# The max temperature of Petrovskoye today  is: 9 and the weather is broken clouds
# The max temperature of Tateyama today  is: 16.11 and the weather is moderate rain
# The max temperature of Meulaboh today  is: 26.44 and the weather is light rain
# The max temperature of Nepomuceno today  is: 20.64 and the weather is light rain
# The max temperature of Amuntai today  is: 21.67 and the weather is overcast clouds
# The max temperature of Correntina today  is: 28.05 and the weather is light rain
# The max temperature of Clyde River today  is: 0 and the weather is overcast clouds
# The max temperature of Lagunas today  is: 31.45 and the weather is broken clouds
# The max temperature of Trinidad today  is: 26 and the weather is broken clouds
# The max temperature of Baloda Bazar today  is: 21.18 and the weather is broken clouds
# The max temperature of Galveston today  is: 19 and the weather is moderate rain
# The max temperature of Polunochnoye today  is: 2 and the weather is light rain
# The max temperature of Hun today  is: 12.22 and the weather is broken clouds
# The max temperature of Alice Springs today  is: 12 and the weather is scattered clouds
# The max temperature of Marshall today  is: 14.44 and the weather is overcast clouds
# The max temperature of Santiago del Estero today  is: 27.72 and the weather is clear sky
# The max temperature of Hare Bay today  is: 6 and the weather is light intensity shower rain
# The max temperature of Verkhovye today  is: 10.75 and the weather is broken clouds
# The max temperature of Mount Isa today  is: 20 and the weather is clear sky
# The max temperature of Palu today  is: 16.61 and the weather is scattered clouds
# The max temperature of Tandil today  is: 18.89 and the weather is light rain
# The max temperature of Imeni Babushkina today  is: 2.81 and the weather is overcast clouds

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#reformatting and cleaning data

citiesTemperature["Temperature"]=pd.to_numeric(citiesTemperature["Temperature"], downcast='float')
citiesTemperature["Longtitude"]=pd.to_numeric(citiesTemperature["Longtitude"], downcast='float')
citiesTemperature["Latitude"]=pd.to_numeric(citiesTemperature["Latitude"], downcast='float')
citiesTemperature["Humidity"]=pd.to_numeric(citiesTemperature["Humidity"], downcast='float')
citiesTemperature["Wind speed"]=pd.to_numeric(citiesTemperature["Wind speed"], downcast='float')
citiesTemperature["Cloudiness"]=pd.to_numeric(citiesTemperature["Cloudiness"], downcast='float')


citiesTemperature=citiesTemperature.dropna(how="any")

citiesTemperature.dtypes
citiesTemperature.to_csv("Weather Report.csv",index=False)
citiesTemperature.head()
# Out:
#          Cities   Latitude  Longtitude  Temperature  Humidity  Wind speed  \
# 0       Chapais  49.779999  -74.860001         9.00      70.0        2.10
# 1   Songjianghe  42.180000  127.480003         4.73      92.0        1.91
# 2  Puerto Ayora  -0.740000  -90.349998        24.00      60.0        7.70
# 3    Oranjestad  12.520000  -70.029999        31.00      62.0        6.20
# 4     Bathsheba  13.220000  -59.520000        29.00      66.0        5.70
#
#    Cloudiness
# 0        90.0
# 1         0.0
# 2        90.0
# 3        20.0
# 4        20.0

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#defining axis:
x_axis=citiesTemperature["Latitude"]
y=citiesTemperature["Temperature"]


#plotting the axises
plt.scatter(x_axis, y,marker ='.',
            linewidth=0.5,
            label="Today's max temperature of random cities",
            facecolors="red", edgecolors="black",
            s=2*y)
#plt.grid(axis='x')

#adding legend and titles
plt.title(f"Latitude vs. Temperature Plot on: \n {DateRetrieved}")
plt.xlabel("Latitude")
plt.ylabel("Temperature (Celsius)")
plt.vlines(0,-20,40, alpha=1, color='blue', label='the Equator', linestyles='dotted')
plt.legend(loc='best', shadow = True) 


# Show the Figure
plt.savefig("Images/Latitude vs. Temperature Plot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#defining axis:
x_axis=citiesTemperature["Latitude"]
y=citiesTemperature["Humidity"]


#plotting the axises
plt.scatter(x_axis, y,marker ='.', color='green', linewidth=0, label="Humidity levels at Random cities")
#plt.grid(axis='x')

#adding legend and titles
plt.title(f"Latitude vs. Humidity Plot on: \n {DateRetrieved}")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.vlines(0,0,100, alpha=1, color='red', label='the Equator', linestyles='dotted')
plt.legend(loc='best', framealpha =1,shadow = True ) 


# Show the Figure
plt.savefig("Images/Latitude vs. Humidity Plot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#defining axis:
x_axis=citiesTemperature["Latitude"]
y=citiesTemperature["Cloudiness"]


#plotting the axises
plt.scatter(x_axis, y,marker ='.', color='blue', linewidth=0,label="Cloudiness %")
#plt.grid(axis='x')

#adding legend and titles
plt.title(f"Latitude vs. Cloudiness Plot on: \n {DateRetrieved}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness, %")
plt.vlines(0,0,100,
           color='red',
           label='the Equator',
           linestyles='dotted',
           linewidth=2)

plt.legend(loc='best', shadow = True) 


# Show the Figure
plt.savefig("Images/Latitude vs. Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#defining axis:
x_axis=citiesTemperature["Latitude"]
y=citiesTemperature["Wind speed"]


#plotting the axises
plt.scatter(x_axis,
            y,marker ='.',
            color='black',
            linewidth=1,
            label="Wind speed at random cities",
            )
#plt.grid(axis='x')

#adding legend and titles
plt.title(f"Latitude vs. Wind speed Plot on: \n {DateRetrieved}" )
plt.xlabel("Latitude")
plt.ylabel("Wind speed ( meter/sec)")
plt.vlines(0,0,18, alpha=1, color='red', label='the Equator', linestyles='dotted', linewidth=3)
plt.legend(loc='best', shadow = True) 


# Show the Figure
plt.savefig("Images/Latitude vs. Wind speed Plot.png")
plt.show()

# %% [markdown]
# ## Observations
#
# 1. There seems to be a strong visual indication of a relationship between current temperature and proximity to the equator. As cities are located closer to the equator the current temperature seems to rise.
#
# 2. There is no visual indication of any relationship between humidity and cloudiness.
#
# 3. But there seems to be some correlation between current wind speed and proximity to the Equator.

# %%
import pandas as pd

# %%
file="data/Scoring.csv"
data=pd.read_csv(file)
data.head(20)
# Out:
#      playerID  year  stint tmID lgID pos    GP    G     A   Pts  ...  PostA  \
# 0   aaltoan01  1997      1  ANA  NHL   C   3.0  0.0   0.0   0.0  ...    NaN
# 1   aaltoan01  1998      1  ANA  NHL   C  73.0  3.0   5.0   8.0  ...    0.0
# 2   aaltoan01  1999      1  ANA  NHL   C  63.0  7.0  11.0  18.0  ...    NaN
# 3   aaltoan01  2000      1  ANA  NHL   C  12.0  1.0   1.0   2.0  ...    NaN
# 4   abbeybr01  1975      1  CIN  WHA   D  17.0  1.0   0.0   1.0  ...    NaN
# 5   abbotge01  1943      1  BOS  NHL   G   1.0  0.0   0.0   0.0  ...    NaN
# 6   abbotre01  1952      1  MTL  NHL   C   3.0  0.0   0.0   0.0  ...    NaN
# 7   abdelju01  2007      1  DET  NHL   L   2.0  0.0   0.0   0.0  ...    NaN
# 8   abdelju01  2008      1  DET  NHL   L   2.0  0.0   0.0   0.0  ...    1.0
# 9   abdelju01  2009      1  DET  NHL   L  50.0  3.0   3.0   6.0  ...    1.0
# 10  abdelju01  2010      1  DET  NHL   L  74.0  7.0  12.0  19.0  ...    0.0
# ...

# %%
players=data[["playerID", "year","GP","G","A"]].groupby(["playerID", "year"]).sum()
stat=players.groupby("playerID").cumsum()
stat=pd.DataFrame(stat)
stat.head(50)
stat.to_csv("SumofGoals.csv")

# %%
stat.dtypes
# Out:
# GP    float64
# G     float64
# A     float64
# dtype: object

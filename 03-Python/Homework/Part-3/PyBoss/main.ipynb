# %%
import pandas as pd

# %%
file="employee_data.csv"
emp = pd.read_csv(file)
emp.head()
# Out:
#    Emp ID              Name         DOB          SSN         State
# 0     232      John Mathews  1991-02-24  289-31-9165  North Dakota
# 1     533      Nathan Moore  1978-11-19  220-05-7469         Maine
# 2     256    Amanda Douglas  1990-01-08  564-27-6961         Idaho
# 3     189   Heather Andrews  1976-08-11  742-79-1797       Vermont
# 4     284  Daniel Hernandez  1976-07-22  656-01-7473      Colorado

# %%
emp.info()

# %%
#The `Name` column should be split into separate `First Name` and `Last Name` columns.
emp[['First','Last']] = emp.Name.str.split(expand=True) 

emp.head()
# Out:
#    Emp ID              Name         DOB          SSN         State    First  \
# 0     232      John Mathews  1991-02-24  289-31-9165  North Dakota     John
# 1     533      Nathan Moore  1978-11-19  220-05-7469         Maine   Nathan
# 2     256    Amanda Douglas  1990-01-08  564-27-6961         Idaho   Amanda
# 3     189   Heather Andrews  1976-08-11  742-79-1797       Vermont  Heather
# 4     284  Daniel Hernandez  1976-07-22  656-01-7473      Colorado   Daniel
#
#         Last
# 0    Mathews
# 1      Moore
# 2    Douglas
# 3    Andrews
# 4  Hernandez

# %%
#* The `DOB` data should be re-written into `MM/DD/YYYY` format.

emp["DOB_Modified"]= pd.to_datetime(emp['DOB'])
emp["DOB"] = emp['DOB_Modified'].dt.strftime('%m/%d/%Y')
emp.head()
# Out:
#    Emp ID              Name         DOB          SSN         State    First  \
# 0     232      John Mathews  02/24/1991  289-31-9165  North Dakota     John
# 1     533      Nathan Moore  11/19/1978  220-05-7469         Maine   Nathan
# 2     256    Amanda Douglas  01/08/1990  564-27-6961         Idaho   Amanda
# 3     189   Heather Andrews  08/11/1976  742-79-1797       Vermont  Heather
# 4     284  Daniel Hernandez  07/22/1976  656-01-7473      Colorado   Daniel
#
#         Last DOB_Modified
# 0    Mathews   1991-02-24
# 1      Moore   1978-11-19
# 2    Douglas   1990-01-08
# 3    Andrews   1976-08-11
# 4  Hernandez   1976-07-22

# %%
# The `SSN` data should be re-written such that the first five numbers are hidden from view.
emp['SSN'] = "***-**-" + emp['SSN'].str[7:11]
emp.head()
# Out:
#    Emp ID              Name         DOB          SSN         State    First  \
# 0     232      John Mathews  02/24/1991  ***-**-9165  North Dakota     John
# 1     533      Nathan Moore  11/19/1978  ***-**-7469         Maine   Nathan
# 2     256    Amanda Douglas  01/08/1990  ***-**-6961         Idaho   Amanda
# 3     189   Heather Andrews  08/11/1976  ***-**-1797       Vermont  Heather
# 4     284  Daniel Hernandez  07/22/1976  ***-**-7473      Colorado   Daniel
#
#         Last DOB_Modified
# 0    Mathews   1991-02-24
# 1      Moore   1978-11-19
# 2    Douglas   1990-01-08
# 3    Andrews   1976-08-11
# 4  Hernandez   1976-07-22

# %%
# The `State` data should be re-written as simple two-letter abbreviations.
#create state abbreviation dataframe
state=pd.DataFrame ({
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-6bb008d57afc> in <module>
#      51     'West Virginia': 'WV',
#      52     'Wisconsin': 'WI',
# ---> 53     'Wyoming': 'WY',
#      54 })
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
# ...
